# %%
import numpy as np

import pandas as pd

from pandas import Series, DataFrame

# %%
obj= Series([3,6,9,12])

obj
# Out:
# 0     3
# 1     6
# 2     9
# 3    12
# dtype: int64

# %%
obj.values
# Out:
# array([ 3,  6,  9, 12], dtype=int64)

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
ww2=Series([87000000,4300000,300000], index=['USSR','Germany', 'Japan'])

ww2
# Out:
# USSR       87000000
# Germany     4300000
# Japan        300000
# dtype: int64

# %%
ww2['Germany']
# Out:
# 4300000

# %%
ww2[ww2>50000]
# Out:
# USSR       87000000
# Germany     4300000
# Japan        300000
# dtype: int64

# %%
'Germany' in ww2
# Out:
# True

# %%
ww2_dict=ww2.to_dict()
ww2_dict
# Out:
# {'USSR': 87000000, 'Germany': 4300000, 'Japan': 300000}

# %%
ww2_series=Series(ww2_dict)

# %%
ww2_series
# Out:
# USSR       87000000
# Germany     4300000
# Japan        300000
# dtype: int64

# %%
countries=['USSR','Germany', 'Japan','Greece']

# %%
obj2=Series(ww2_dict,index=countries)

# %%
obj2
# Out:
# USSR       87000000
# Germany     4300000
# Japan        300000
# dtype: int64

# %%
pd.isnull(obj2)
# Out:
# USSR       False
# Germany    False
# Japan      False
# dtype: bool

# %%
ww2_series + obj2
# Out:
# USSR       174000000
# Germany      8600000
# Japan         600000
# dtype: int64

# %%
obj2.name='ileana'

# %%
obj2
# Out:
# USSR       87000000
# Germany     4300000
# Japan        300000
# dtype: int64

# %%
obj2
# Out:
# USSR       87000000
# Germany     4300000
# Japan        300000
# dtype: int64

# %%
obj2.index.name='Countries'

# %%
obj2
# Out:
# Countries
# USSR       87000000
# Germany     4300000
# Japan        300000
# dtype: int64
