# %%
import numpy as np

# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
import webbrowser
website='http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame=pd.read_clipboard()
nfl_frame
# Out:
#         Rank     Team        GP    Won  Lost  Tied    Pct.     First   NFL  \
# 1      Green      Bay   Packers  1,384   769   577  38.000     0.569  1921
# 2     Dallas  Cowboys       930    526   398     6   0.569  1960.000   NFC
# 3  Baltimore   Ravens       400    225   174     1   0.564  1996.000   AFC
# 4    Chicago    Bears     1,418    777   599    42   0.563  1920.000   NFC
# 5        New  England  Patriots    932   519   404   9.000     0.562  1960
#
#   season Division
# 1    NFC    North
# 2   East     None
# 3  North     None
# 4  North     None
# 5    AFC     East

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First', 'NFL',
#        'season', 'Division'],
#       dtype='object')

# %%
nfl_frame['Lost']
# Out:
# 1    769
# 2    398
# 3    174
# 4    599
# 5    519
# Name: Lost, dtype: int64

# %%
DataFrame(nfl_frame,columns=['GP','Won','Tied','First'])
# Out:
#          GP    Won  Tied     First
# 1   Packers  1,384   577     0.569
# 2       930    526     6  1960.000
# 3       400    225     1  1996.000
# 4     1,418    777    42  1920.000
# 5  Patriots    932   404     0.562

# %%
DataFrame(nfl_frame,columns=['GP','Won','Tied','First', 'Country'])
# Out:
#          GP    Won  Tied     First  Country
# 1   Packers  1,384   577     0.569      NaN
# 2       930    526     6  1960.000      NaN
# 3       400    225     1  1996.000      NaN
# 4     1,418    777    42  1920.000      NaN
# 5  Patriots    932   404     0.562      NaN

# %%
nfl_frame.head(3)
# Out:
#         Rank     Team       GP    Won  Lost  Tied    Pct.     First   NFL  \
# 1      Green      Bay  Packers  1,384   769   577  38.000     0.569  1921
# 2     Dallas  Cowboys      930    526   398     6   0.569  1960.000   NFC
# 3  Baltimore   Ravens      400    225   174     1   0.564  1996.000   AFC
#
#   season Division
# 1    NFC    North
# 2   East     None
# 3  North     None

# %%
nfl_frame.tail(2)
# Out:
#       Rank     Team        GP  Won  Lost  Tied   Pct.     First   NFL season  \
# 4  Chicago    Bears     1,418  777   599    42  0.563  1920.000   NFC  North
# 5      New  England  Patriots  932   519   404  9.000     0.562  1960    AFC
#
#   Division
# 4     None
# 5     East

# %%
nfl_frame.iloc[3]
# Out:
# Rank        Chicago
# Team          Bears
# GP            1,418
# Won             777
# Lost            599
# Tied             42
# Pct.          0.563
# First          1920
# NFL             NFC
# season        North
# Division       None
# Name: 4, dtype: object

# %%
nfl_frame['Country']='Greece'

# %%
nfl_frame
# Out:
#         Rank    Team        GP    Won  Lost  Tied    Pct.     First   NFL  \
# 1      Green  Greece   Packers  1,384   769   577  38.000     0.569  1921
# 2     Dallas  Greece       930    526   398     6   0.569  1960.000   NFC
# 3  Baltimore  Greece       400    225   174     1   0.564  1996.000   AFC
# 4    Chicago  Greece     1,418    777   599    42   0.563  1920.000   NFC
# 5        New  Greece  Patriots    932   519   404   9.000     0.562  1960
#
#   season Division Country
# 1    NFC    North  Greece
# 2   East     None  Greece
# 3  North     None  Greece
# 4  North     None  Greece
# 5    AFC     East  Greece

# %%
nfl_frame['Country']=np.arange(5)
nfl_frame
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-fc89f6647be8> in <module>
# ----> 1 nfl_frame['Country']=np.arange(5)
#       2 nfl_frame
#
# ~\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'arange'

# %%
countries=Series(["Greece", "Portugal", "Netherlands"],index=[1,4,5])
countries
# Out:
# 1         Greece
# 4       Portugal
# 5    Netherlands
# dtype: object

# %%
nfl_frame['Country']=countries
nfl_frame
# Out:
#         Rank    Team        GP    Won  Lost  Tied    Pct.     First   NFL  \
# 1      Green  Greece   Packers  1,384   769   577  38.000     0.569  1921
# 2     Dallas  Greece       930    526   398     6   0.569  1960.000   NFC
# 3  Baltimore  Greece       400    225   174     1   0.564  1996.000   AFC
# 4    Chicago  Greece     1,418    777   599    42   0.563  1920.000   NFC
# 5        New  Greece  Patriots    932   519   404   9.000     0.562  1960
#
#   season Division      Country
# 1    NFC    North       Greece
# 2   East     None          NaN
# 3  North     None          NaN
# 4  North     None     Portugal
# 5    AFC     East  Netherlands

# %%
del nfl_frame['Country']
nfl_frame
# Out:
#         Rank    Team        GP    Won  Lost  Tied    Pct.     First   NFL  \
# 1      Green  Greece   Packers  1,384   769   577  38.000     0.569  1921
# 2     Dallas  Greece       930    526   398     6   0.569  1960.000   NFC
# 3  Baltimore  Greece       400    225   174     1   0.564  1996.000   AFC
# 4    Chicago  Greece     1,418    777   599    42   0.563  1920.000   NFC
# 5        New  Greece  Patriots    932   519   404   9.000     0.562  1960
#
#   season Division
# 1    NFC    North
# 2   East     None
# 3  North     None
# 4  North     None
# 5    AFC     East

# %%
data={'City': [ 'GR', 'NL', 'PT'], 'Population': [5000,6000,700] }

# %%
city_frame=DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   GR        5000
# 1   NL        6000
# 2   PT         700
