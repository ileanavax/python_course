# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
ser1=Series(range(3),index=['A', 'B', 'C'])

# %%
ser1
# Out:
# A    0
# B    1
# C    2
# dtype: int64

# %%
ser1.sort_index()
# Out:
# A    0
# B    1
# C    2
# dtype: int64

# %%
from numpy.random import randn

# %%
ser2=Series(randn(10))
ser2
# Out:
# 0    0.294769
# 1   -0.232035
# 2    0.898386
# 3   -0.054024
# 4   -1.221941
# 5    1.736575
# 6   -0.052686
# 7   -0.639483
# 8   -0.651394
# 9    0.144284
# dtype: float64

# %%
ser2.sort_index()
# Out:
# 0    0.294769
# 1   -0.232035
# 2    0.898386
# 3   -0.054024
# 4   -1.221941
# 5    1.736575
# 6   -0.052686
# 7   -0.639483
# 8   -0.651394
# 9    0.144284
# dtype: float64

# %%
ser2.rank()
# Out:
# 0     8.0
# 1     4.0
# 2     9.0
# 3     5.0
# 4     1.0
# 5    10.0
# 6     6.0
# 7     3.0
# 8     2.0
# 9     7.0
# dtype: float64

# %%
ser3=Series(randn(15))

# %%
ser3
# Out:
# 0    -0.807649
# 1     0.233063
# 2     1.045834
# 3     0.466956
# 4     0.524929
# 5     0.493837
# 6     0.415325
# 7     1.410426
# 8    -0.906294
# 9    -0.614151
# 10   -0.895721
# 11   -0.214553
# 12    1.546039
# 13   -1.159379
# 14    0.421425
# dtype: float64

# %%
ser
