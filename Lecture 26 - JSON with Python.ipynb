# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
json_obj="""
{"zoo_animal": "Lion", "food": ["Meat", "Chicken"], "clothes":null}
"""

# %%
import json

# %%
data=json.loads(json_obj)

# %%
data
# Out:
# {'zoo_animal': 'Lion', 'food': ['Meat', 'Chicken'], 'clothes': None}

# %%
json.dumps(data)
# Out:
# '{"zoo_animal": "Lion", "food": ["Meat", "Chicken"], "clothes": null}'

# %%
dframe=DataFrame(data[ 'diet'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-4e6415e90f57> in <module>
# ----> 1 dframe=DataFrame(data[ 'diet'])
#
# KeyError: 'diet'
