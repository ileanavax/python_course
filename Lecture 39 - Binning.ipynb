# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
years=[1990,1991,1992,2008,2012,2013,2029]

# %%
decade_bins=[1960,1970,1990,2000]

# %%
decade_cat=pd.cut(years,decade_bins)

# %%
decade_cat
# Out:
# [(1970.0, 1990.0], (1990.0, 2000.0], (1990.0, 2000.0], NaN, NaN, NaN, NaN]
# Categories (3, interval[int64]): [(1960, 1970] < (1970, 1990] < (1990, 2000]]

# %%
decade_cat.categories
# Out:
# IntervalIndex([(1960, 1970], (1970, 1990], (1990, 2000]],
#               closed='right',
#               dtype='interval[int64]')

# %%
pd.value_counts(decade_cat)
# Out:
# (1990, 2000]    2
# (1970, 1990]    1
# (1960, 1970]    0
# dtype: int64

# %%
pd.cut(years,2,precision=1)
# Out:
# [(1990.0, 2009.5], (1990.0, 2009.5], (1990.0, 2009.5], (1990.0, 2009.5], (2009.5, 2029.0], (2009.5, 2029.0], (2009.5, 2029.0]]
# Categories (2, interval[float64]): [(1990.0, 2009.5] < (2009.5, 2029.0]]
