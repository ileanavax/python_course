# %%
# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd

# Import the stats librayr from numpy
from scipy import stats

# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %%
dataset1=randn(100)

# %%
dataset1
# Out:
# array([-2.00688940e-01,  1.54047871e+00,  5.57903619e-01, -1.34587527e+00,
#        -9.84196920e-01,  5.55700920e-01,  3.77468782e-01,  9.84210861e-01,
#         8.21832840e-01, -7.93075087e-01, -4.05460836e-01,  1.89692920e-01,
#        -9.66108775e-01,  5.77119334e-01, -8.91684862e-01,  9.42453009e-01,
#        -1.65301921e-01,  6.51973097e-01, -1.03000703e-01, -5.54204018e-01,
#        -3.25488819e-02, -1.89716919e-01,  6.66397333e-01, -7.31370613e-01,
#        -2.72156284e-01,  5.82961123e-01,  2.45783354e-01,  3.97185314e-01,
#        -1.37550866e+00, -9.89239031e-01, -1.20340872e+00,  7.90011633e-01,
#         5.77077092e-01,  1.60971339e+00,  9.37751569e-01, -7.38431386e-04,
#         6.14338257e-01, -2.24137019e-01, -5.37257953e-01,  7.14343317e-01,
#        -1.15261297e+00,  6.54262490e-01, -1.11256269e-01, -2.90295674e-01,
#         1.59379425e-01,  5.81557807e-01, -1.19154503e+00, -3.17558148e-01,
#         4.67403004e-01,  1.00189397e+00, -5.70572859e-01, -2.02553346e-02,
#         3.19418421e-01,  8.39139117e-02,  1.12227484e+00, -1.49739833e+00,
#        -3.71074268e-01,  9.07628794e-01, -6.24361612e-01, -1.49288166e+00,
#         8.76746105e-02, -1.72089946e+00, -4.06716067e-02, -2.45508231e-01,
#         2.26778075e-01, -7.94108200e-01, -1.76832920e+00,  2.07245906e+00,
#         3.81861436e-01, -2.67324277e-01,  1.40715972e+00,  4.63752396e-01,
#         1.19352701e+00,  1.07742614e+00, -4.37899634e-01, -9.06822276e-01,
#        -4.07204988e-01,  1.44304704e-01,  1.66630351e+00, -1.59216481e-01,
#         6.86624911e-01,  1.09039256e-01,  1.31550151e-01,  2.06124154e+00,
#        -5.01880291e-01, -1.49840011e+00,  1.10193981e+00, -4.58723572e-01,
#         1.12342027e+00, -6.63225829e-01,  4.73947182e-01,  1.06285331e+00,
#        -5.35444918e-01, -4.61393752e-01, -1.83807362e+00,  4.93471660e-01,
#        -2.85792750e-02, -5.71728433e-02,  1.62725332e-01,  8.01670393e-01])

# %%
plt.hist(dataset1)
# Out:
# (array([ 6.,  5.,  8., 15., 19., 15., 15., 11.,  4.,  2.]),
#  array([-1.83807362, -1.44702035, -1.05596708, -0.66491381, -0.27386055,
#          0.11719272,  0.50824599,  0.89929926,  1.29035253,  1.68140579,
#          2.07245906]),
#  <BarContainer object of 10 artists>)

# %%
dataset2=randn(80)

# %%
plt.hist(dataset2,color='indianred')
# Out:
# (array([ 2.,  4.,  7.,  7., 14., 10., 12., 14.,  6.,  4.]),
#  array([-2.41902448, -1.97664254, -1.5342606 , -1.09187865, -0.64949671,
#         -0.20711477,  0.23526717,  0.67764911,  1.12003105,  1.562413  ,
#          2.00479494]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(dataset1,color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2,alpha=0.5,bins=20)
# Out:
# (array([1., 1., 2., 2., 3., 4., 3., 4., 7., 7., 4., 6., 8., 4., 5., 9., 2.,
#         4., 2., 2.]),
#  array([-2.41902448, -2.19783351, -1.97664254, -1.75545157, -1.5342606 ,
#         -1.31306963, -1.09187865, -0.87068768, -0.64949671, -0.42830574,
#         -0.20711477,  0.0140762 ,  0.23526717,  0.45645814,  0.67764911,
#          0.89884008,  1.12003105,  1.34122202,  1.562413  ,  1.78360397,
#          2.00479494]),
#  <BarContainer object of 20 artists>)

# %%
data1=randn(1000)
data2=randn(1000)

# %%
sns.jointplot(data1,data2)
# Out:
# C:\Users\ivaxevani\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(data1,data2,kind='hex')
# Out:
# C:\Users\ivaxevani\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
