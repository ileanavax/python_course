# %%
cities=['AMS','BCN', 'LN']

# %%
city=cities[0]

if city=='NY':
    print('party')
elif city=='AMS':
    print('yeah')
else:
    print('no')
# Out:
# yeah

# %%
for city in cities:
    if city=='NY':
        print('party')
    elif city=='AMS':
        print('yeah')
    else:
        print('no')
# Out:
# yeah
# no
# no

# %%
t=(10,4,5,7,8)

# %%
t
# Out:
# (10, 4, 5, 7, 8)

# %%
my_dict={'Joe':22,'Ileana':21,'Nikol':25}

# %%
my_dict['Ileana']
# Out:
# 21

# %%
len(my_dict)
# Out:
# 3

# %%
def adder(x,y):
    answer=x+y
    return answer

# %%
adder(10,15)
# Out:
# 25
